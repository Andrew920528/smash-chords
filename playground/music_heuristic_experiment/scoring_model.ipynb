# %% [markdown]
# # SmashChords Scoring Model
#
# Heuristic scoring functions for matching snippets.
#
# - **`key_score`** — similarity based on circle-of-fifths distance between two keys
# - **`progression_score`** — similarity based on chord-sequence comparison (pluggable distance function)
# - **`score_all`** — given a query snippet, score every snippet in the dataset

# %% [markdown]
# ## Load Data

# %%
import ast
import pandas as pd

df = pd.read_csv("toy_smashchords_tswift.csv")
df["roman_progression"] = df["roman_progression"].apply(ast.literal_eval)
df["chord_progression_raw"] = df["chord_progression_raw"].apply(ast.literal_eval)

print(f"Loaded {len(df)} snippets across {df['song_title'].nunique()} songs")
df.head()
# Out:
# Loaded 1163 snippets across 234 songs
#   snippet_id                  song_title section        artist key key_mode  \
# 0     TS_001                       seven   Verse  Taylor Swift   G    major
# 1     TS_002                       seven  Chorus  Taylor Swift   D    minor
# 2     TS_003                       seven  Bridge  Taylor Swift   A    minor
# 3     TS_004                       seven   Outro  Taylor Swift   A    minor
# 4     TS_005  it's nice to have a friend   Intro  Taylor Swift   A    minor
#
#     roman_progression chord_progression_raw
# 0          [I, v, IV]            [G, Dm, C]
# 1   [i, VII, III, IV]         [Dm, C, F, G]
# 2       [i, III, VII]            [Am, C, G]
# 3  [i, III, VII, III]         [Am, C, G, C]
# 4            [i, VII]               [Am, G]

# %% [markdown]
# ---
# ## Key Score
#
# Each key is a node on the circle of fifths (12 nodes). Distance is the shortest arc between two nodes (0–6 steps).
#
# Linear mapping: `key_score = 1 - distance / 6`
# - Same key → distance 0 → score **1.0**
# - Opposite key → distance 6 → score **0.0**

# %%
# Circle of fifths (12 nodes, ordered)
CIRCLE_OF_FIFTHS = ["C", "G", "D", "A", "E", "B", "F#", "C#", "Ab", "Eb", "Bb", "F"]

# Enharmonic equivalents → canonical form
ENHARMONIC = {
    "Db": "C#", "Gb": "F#", "Cb": "B",
    "Fb": "E",  "E#": "F", "B#": "C",
    "A#": "Bb", "D#": "Eb", "G#": "Ab",
}

def _normalize_key(key: str) -> str | None:
    """Resolve enharmonic spellings to the canonical circle-of-fifths label."""
    if key is None or (isinstance(key, float)):
        return None
    key = str(key).strip()
    return ENHARMONIC.get(key, key)

def circle_distance(key_a: str, key_b: str) -> int | None:
    """
    Shortest arc distance between two keys on the circle of fifths.
    Returns an int in [0, 6], or None if either key is unrecognized.
    """
    a = _normalize_key(key_a)
    b = _normalize_key(key_b)
    if a not in CIRCLE_OF_FIFTHS or b not in CIRCLE_OF_FIFTHS:
        return None
    i, j = CIRCLE_OF_FIFTHS.index(a), CIRCLE_OF_FIFTHS.index(b)
    d = abs(i - j)
    return min(d, len(CIRCLE_OF_FIFTHS) - d)  # shortest arc

def key_score(key_a: str, key_b: str) -> float:
    """
    Similarity score in [0, 1] based on circle-of-fifths distance.
    Same key → 1.0.  Opposite key (tritone, 6 steps) → 0.0.
    Returns 0.5 if either key is unrecognized.
    """
    d = circle_distance(key_a, key_b)
    if d is None:
        return 0.5  # unknown key: neutral score
    return 1.0 - d / 6.0

# --- Quick sanity check ---
tests = [("C", "C"), ("C", "G"), ("C", "F#"), ("C", "Db")]
for a, b in tests:
    print(f"key_score({a!r}, {b!r}) = {key_score(a, b):.4f}  (distance={circle_distance(a, b)})")
# Out:
# key_score('C', 'C') = 1.0000  (distance=0)
# key_score('C', 'G') = 0.8333  (distance=1)
# key_score('C', 'F#') = 0.0000  (distance=6)
# key_score('C', 'Db') = 0.1667  (distance=5)

# %%
def key_scores_for_song(song_key: str, df: pd.DataFrame) -> pd.DataFrame:
    """
    Given a song's key, return a copy of df with a `key_score` column
    showing how closely each snippet's key matches.
    """
    result = df.copy()
    result["key_score"] = result["key"].apply(lambda k: key_score(song_key, k))
    return result.sort_values("key_score", ascending=False)

# Demo: score all snippets against the key of "C"
scored = key_scores_for_song("C", df)
print("All snippets scored by key proximity to C major:")
print(scored[["snippet_id", "song_title", "section", "key", "key_score"]].to_string(index=False))
# Out:
# All snippets scored by key proximity to C major:
# snippet_id                                                           song_title     section key  key_score
#     TS_605                                                                karma      Bridge   C   1.000000
#     TS_949                                                            labyrinth       Verse   C   1.000000
#     TS_227                                                      thank you aimee       Verse   C   1.000000
#     TS_226                                                      thank you aimee       Intro   C   1.000000
#     TS_944                                                           the archer  Pre-Chorus   C   1.000000
#     TS_945                                                           the archer      Chorus   C   1.000000
#     TS_946                                                           the archer      Bridge   C   1.000000
#     TS_947                                                           the archer       Outro   C   1.000000
#     TS_948                                                            labyrinth       Intro   C   1.000000
#     TS_951                                                            labyrinth      Chorus   C   1.000000
#     TS_231                                                      thank you aimee       Outro   C   1.000000
#     TS_952                                                            labyrinth Post-Chorus   C   1.000000
#     TS_953                                                          getaway car       Verse   C   1.000000
#     TS_954                                                          getaway car  Pre-Chorus   C   1.000000
#     TS_214              message in a bottle (taylor's version) (from the vault)      Bridge   C   1.000000
#     TS_431                                          dancing with our hands tied      Bridge   C   1.000000
#     TS_834                                                     king of my heart  Pre-Chorus   C   1.000000
#     TS_833                                                     king of my heart       Verse   C   1.000000
#     TS_228                                                      thank you aimee  Pre-Chorus   C   1.000000
#     TS_232                                                                robin       Intro   C   1.000000
#     TS_831                                     i know places (taylor's version)      Bridge   C   1.000000
#     TS_839                                                             daylight      Chorus   C   1.000000
#     TS_843                                              mine (taylor's version)       Intro   C   1.000000
#     TS_934                  is it over now? (taylor's version) (from the vault) Post-Chorus   C   1.000000
#     TS_935                  is it over now? (taylor's version) (from the vault)      Bridge   C   1.000000
#     TS_842                                                             daylight       Outro   C   1.000000
#     TS_937                                                          the alchemy       Verse   C   1.000000
#     TS_841                                                             daylight      Bridge   C   1.000000
#     TS_840                                                             daylight Post-Chorus   C   1.000000
#     TS_838                                                             daylight       Verse   C   1.000000
#     TS_233                                                                robin       Verse   C   1.000000
#     TS_939                                                          the alchemy      Chorus   C   1.000000
#     TS_940                                                          the alchemy Post-Chorus   C   1.000000
#     TS_836                                                     king of my heart Post-Chorus   C   1.000000
#     TS_238                      foolish one (taylor's version) (from the vault)  Pre-Chorus   C   1.000000
#     TS_835                                                     king of my heart      Chorus   C   1.000000
#     TS_941                                                          the alchemy      Bridge   C   1.000000
#     TS_942                                                          the alchemy       Outro   C   1.000000
#     TS_208                             today was a fairytale (taylor's version)      Bridge   C   1.000000
#     TS_206                             today was a fairytale (taylor's version)  Pre-Chorus   C   1.000000
#     TS_812                                                               maroon       Intro   C   1.000000
#     TS_814                                                               maroon      Chorus   C   1.000000
#     TS_971                                                             delicate      Chorus   C   1.000000
#     TS_973                                                             delicate       Outro   C   1.000000
#     TS_452                                                         the prophecy       Intro   C   1.000000
#     TS_453                                                         the prophecy       Verse   C   1.000000
#     TS_977                             come in with the rain (taylor's version)      Chorus   C   1.000000
#     TS_173                                      girl at home (taylor's version)      Bridge   C   1.000000
#     TS_815                                                               maroon      Bridge   C   1.000000
#     TS_457                                             death by a thousand cuts       Intro   C   1.000000
#     TS_969                                                             delicate       Intro   C   1.000000
#     TS_168                                      girl at home (taylor's version)       Intro   C   1.000000
#     TS_813                                                               maroon       Verse   C   1.000000
#     TS_984                                                                paris       Intro   C   1.000000
#     TS_985                                                                paris       Verse   C   1.000000
#     TS_986                                                                paris  Pre-Chorus   C   1.000000
#     TS_987                                                                paris      Chorus   C   1.000000
#     TS_988                                                                paris      Bridge   C   1.000000
#     TS_970                                                             delicate       Verse   C   1.000000
#     TS_968                                                   my tears richochet       Outro   C   1.000000
#     TS_955                                                          getaway car      Chorus   C   1.000000
#     TS_819                                                        the great war      Bridge   C   1.000000
#     TS_201                                                       so high school Post-Chorus   C   1.000000
#     TS_830                                     i know places (taylor's version)      Chorus   C   1.000000
#     TS_199                                                       so high school       Verse   C   1.000000
#     TS_198                                                       so high school       Intro   C   1.000000
#     TS_441                                                     no body no crime      Bridge   C   1.000000
#     TS_826                                       who's afraid of little old me?       Outro   C   1.000000
#     TS_823                                       who's afraid of little old me?      Chorus   C   1.000000
#     TS_192                                    stay stay stay (taylor's version)       Verse   C   1.000000
#     TS_967                                                   my tears richochet      Bridge   C   1.000000
#     TS_191                                    stay stay stay (taylor's version)       Intro   C   1.000000
#     TS_959                                                            bejeweled       Verse   C   1.000000
#     TS_960                                                            bejeweled      Chorus   C   1.000000
#     TS_961                                                            bejeweled Post-Chorus   C   1.000000
#     TS_962                                                            bejeweled      Bridge   C   1.000000
#     TS_816                                                               maroon       Outro   C   1.000000
#     TS_966                                                   my tears richochet      Chorus   C   1.000000
#     TS_844                                              mine (taylor's version)       Verse   C   1.000000
#     TS_415                   forever winter (taylor's version) (from the vault)       Outro   C   1.000000
#     TS_414                   forever winter (taylor's version) (from the vault)      Bridge   C   1.000000
#     TS_870             the very first night (taylor's version) (from the vault)      Chorus   C   1.000000
#     TS_891 all too well (10 minute version) (taylor's version) (from the vault)       Verse   C   1.000000
#     TS_892 all too well (10 minute version) (taylor's version) (from the vault)  Pre-Chorus   C   1.000000
#     TS_893 all too well (10 minute version) (taylor's version) (from the vault)      Chorus   C   1.000000
#     TS_894 all too well (10 minute version) (taylor's version) (from the vault)      Bridge   C   1.000000
#     TS_896                    we were happy (taylor's version) (from the vault)       Intro   C   1.000000
#     TS_325                                 my boy only breaks his favorite toys       Outro   C   1.000000
#     TS_871             the very first night (taylor's version) (from the vault) Post-Chorus   C   1.000000
#     TS_317                                                             end game       Intro   C   1.000000
#     TS_872             the very first night (taylor's version) (from the vault)      Bridge   C   1.000000
#     TS_897                    we were happy (taylor's version) (from the vault)       Verse   C   1.000000
#     TS_310                                      i can do it with a broken heart       Verse   C   1.000000
#     TS_898                    we were happy (taylor's version) (from the vault)      Chorus   C   1.000000
#     TS_901                                                   champagne problems       Verse   C   1.000000
#     TS_867             the very first night (taylor's version) (from the vault)       Intro   C   1.000000
#     TS_392                 castles crumbling taylor's version) (from the vault)       Intro   C   1.000000
#     TS_300                                             ronan (taylor's version)      Bridge   C   1.000000
#     TS_890 all too well (10 minute version) (taylor's version) (from the vault)       Intro   C   1.000000
#     TS_873                                 the moment i knew (taylor's version)       Intro   C   1.000000
#     TS_933                  is it over now? (taylor's version) (from the vault)      Chorus   C   1.000000
#     TS_345                                                     long story short       Intro   C   1.000000
#     TS_887                                      all too well (taylor's version)      Chorus   C   1.000000
#     TS_886                                      all too well (taylor's version)  Pre-Chorus   C   1.000000
#     TS_885                                      all too well (taylor's version)       Verse   C   1.000000
#     TS_888                                      all too well (taylor's version)      Bridge   C   1.000000
#     TS_348                                                     long story short Post-Chorus   C   1.000000
#     TS_884                                      all too well (taylor's version)       Intro   C   1.000000
#     TS_881                                                                betty      Chorus   C   1.000000
#     TS_880                                                                betty  Pre-Chorus   C   1.000000
#     TS_889                                      all too well (taylor's version)       Outro   C   1.000000
#     TS_879                                                                betty       Verse   C   1.000000
#     TS_878                                                                betty       Intro   C   1.000000
#     TS_877                                 the moment i knew (taylor's version)       Outro   C   1.000000
#     TS_876                                 the moment i knew (taylor's version)      Bridge   C   1.000000
#     TS_875                                 the moment i knew (taylor's version)      Chorus   C   1.000000
#     TS_874                                 the moment i knew (taylor's version)       Verse   C   1.000000
#     TS_336         i bet you think about me (taylor's version) (from the vault)       Verse   C   1.000000
#     TS_297                                             ronan (taylor's version)       Verse   C   1.000000
#     TS_296                                             ronan (taylor's version)       Intro   C   1.000000
#     TS_902                                                   champagne problems      Chorus   C   1.000000
#     TS_265                                                      picture to burn      Bridge   C   1.000000
#     TS_272                                         starlight (taylor's version)       Intro   C   1.000000
#     TS_918                                  i wish you would (taylor's version)      Bridge   C   1.000000
#     TS_409                   forever winter (taylor's version) (from the vault)       Intro   C   1.000000
#     TS_410                   forever winter (taylor's version) (from the vault)       Verse   C   1.000000
#     TS_919                                  i wish you would (taylor's version)       Outro   C   1.000000
#     TS_926                                        the tortured poets department       Verse   C   1.000000
#     TS_927                                        the tortured poets department      Chorus   C   1.000000
#     TS_411                   forever winter (taylor's version) (from the vault)  Pre-Chorus   C   1.000000
#     TS_903                                                   champagne problems      Bridge   C   1.000000
#     TS_845                                              mine (taylor's version)  Pre-Chorus   C   1.000000
#     TS_262                                                        ready for it?      Bridge   C   1.000000
#     TS_928                                        the tortured poets department      Bridge   C   1.000000
#     TS_413                   forever winter (taylor's version) (from the vault) Post-Chorus   C   1.000000
#     TS_930                  is it over now? (taylor's version) (from the vault)       Intro   C   1.000000
#     TS_931                  is it over now? (taylor's version) (from the vault)       Verse   C   1.000000
#     TS_932                  is it over now? (taylor's version) (from the vault)  Pre-Chorus   C   1.000000
#     TS_846                                              mine (taylor's version)      Chorus   C   1.000000
#     TS_916                                  i wish you would (taylor's version)      Chorus   C   1.000000
#     TS_915                                  i wish you would (taylor's version)       Verse   C   1.000000
#     TS_914                                  i wish you would (taylor's version)       Intro   C   1.000000
#     TS_904                                                   champagne problems       Outro   C   1.000000
#     TS_905                                  out of the woods (taylor's version)       Verse   C   1.000000
#     TS_854           we are never ever getting back together (taylor's version)      Bridge   C   1.000000
#     TS_852           we are never ever getting back together (taylor's version)      Chorus   C   1.000000
#     TS_851           we are never ever getting back together (taylor's version)  Pre-Chorus   C   1.000000
#     TS_288                      nothing new (taylor's version) (from the vault)       Verse   C   1.000000
#     TS_906                                  out of the woods (taylor's version)      Chorus   C   1.000000
#     TS_907                                  out of the woods (taylor's version)      Bridge   C   1.000000
#     TS_908                                                      cornelia street       Intro   C   1.000000
#     TS_909                                                      cornelia street       Verse   C   1.000000
#     TS_911                                                      cornelia street      Chorus   C   1.000000
#     TS_850           we are never ever getting back together (taylor's version)       Verse   C   1.000000
#     TS_849           we are never ever getting back together (taylor's version)       Intro   C   1.000000
#     TS_913                                                      cornelia street       Outro   C   1.000000
#     TS_848                                              mine (taylor's version)       Outro   C   1.000000
#     TS_989                                                                paris       Outro   C   1.000000
#     TS_972                                                             delicate Post-Chorus   C   1.000000
#     TS_811                                                        the black dog       Outro   C   1.000000
#     TS_091                               welcome to new york (taylor's version)       Intro   C   1.000000
#     TS_692                                       untouchable (taylor's version)       Outro   C   1.000000
#     TS_070                                                            invisible  Pre-Chorus   C   1.000000
#     TS_074                                       tell me why (taylor's version)       Verse   C   1.000000
#     TS_992                                       begin again (taylor's version)      Chorus   C   1.000000
#    TS_1072                                                         coney island      Bridge   C   1.000000
#    TS_1071                                                         coney island      Chorus   C   1.000000
#    TS_1070                                                         coney island       Verse   C   1.000000
#    TS_1069                                                         coney island       Intro   C   1.000000
#     TS_086                    electric touch(taylor's version) (from the vault)      Bridge   C   1.000000
#     TS_092                               welcome to new york (taylor's version)       Verse   C   1.000000
#     TS_785                                               a perfectly good heart       Intro   C   1.000000
#     TS_726                        don’t you (taylor's version) (from the vault)       Outro   C   1.000000
#     TS_104                                                22 (taylor's version)       Outro   C   1.000000
#     TS_490                                                                peter      Bridge   C   1.000000
#     TS_487                                                                peter       Verse   C   1.000000
#     TS_486                                                                peter       Intro   C   1.000000
#    TS_1034                                                           question…?      Bridge   C   1.000000
#    TS_1033                                                           question…?      Chorus   C   1.000000
#    TS_1032                                                           question…?       Verse   C   1.000000
#    TS_1031                                                       new year's day       Outro   C   1.000000
#    TS_1104                                                       don't blame me       Intro   C   1.000000
#    TS_1114                                                     it’'s time to go       Intro   C   1.000000
#    TS_1115                                                     it’'s time to go       Verse   C   1.000000
#    TS_1119                                    you're losing me (from the vault)       Verse   C   1.000000
#     TS_603                                                                karma  Pre-Chorus   C   1.000000
#     TS_602                                                                karma       Verse   C   1.000000
#    TS_1140                                                  tis the damn season      Chorus   C   1.000000
#     TS_009                                                        midnight rain  Pre-Chorus   C   1.000000
#     TS_011                                                       the manuscript       Intro   C   1.000000
#     TS_012                                                       the manuscript       Verse   C   1.000000
#     TS_014                                         bad blood (taylor's version)       Verse   C   1.000000
#     TS_015                                         bad blood (taylor's version)  Pre-Chorus   C   1.000000
#     TS_016                                         bad blood (taylor's version)      Bridge   C   1.000000
#     TS_589                                                        lavender haze       Outro   C   1.000000
#    TS_1127           now that we don't talk (taylor's version) (from the vault)       Outro   C   1.000000
#    TS_1125           now that we don't talk (taylor's version) (from the vault)       Verse   C   1.000000
#     TS_027                                                           tim mcgraw       Verse   C   1.000000
#     TS_028                                                           tim mcgraw      Chorus   C   1.000000
#     TS_030                                                           tim mcgraw       Outro   C   1.000000
#     TS_032                                                            mad woman       Verse   C   1.000000
#    TS_1124           now that we don't talk (taylor's version) (from the vault)       Intro   C   1.000000
#    TS_1122                                    you're losing me (from the vault)      Bridge   C   1.000000
#     TS_041                                           fifteen (taylor's version)      Bridge   C   1.000000
#    TS_1030                                                       new year's day      Bridge   C   1.000000
#     TS_077                                       tell me why (taylor's version)       Outro   C   1.000000
#    TS_1024                surburban legends (taylor's version) (from the vault)       Verse   C   1.000000
#     TS_799                                               soon you'll get better       Verse   C   1.000000
#     TS_806                                                        the black dog       Intro   C   1.000000
#    TS_1006                                                             gorgeous      Chorus   C   1.000000
#     TS_795                                              ours (taylor's version)       Verse   C   1.000000
#    TS_1008                                                             gorgeous       Outro   C   1.000000
#    TS_1014                                       white horse (taylor's version)       Intro   C   1.000000
#    TS_1009                                                                 loml       Intro   C   1.000000
#     TS_798                                               soon you'll get better       Intro   C   1.000000
#    TS_1022                                                                  me!      Chorus   C   1.000000
#     TS_800                                               soon you'll get better      Chorus   C   1.000000
#    TS_1003                                                             gorgeous       Intro   C   1.000000
#    TS_1021                                                                  me!  Pre-Chorus   C   1.000000
#     TS_802                                                           the bolter       Intro   C   1.000000
#    TS_1010                                                                 loml       Verse   C   1.000000
#    TS_1011                                                                 loml      Chorus   C   1.000000
#    TS_1020                                                                  me!       Verse   C   1.000000
#     TS_804                                                           the bolter      Chorus   C   1.000000
#    TS_1017                                       white horse (taylor's version)      Chorus   C   1.000000
#     TS_803                                                           the bolter       Verse   C   1.000000
#    TS_1004                                                             gorgeous       Verse   C   1.000000
#    TS_1015                                       white horse (taylor's version)       Verse   C   1.000000
#     TS_807                                                        the black dog       Verse   C   1.000000
#    TS_1027                                                       new year's day       Verse   C   1.000000
#     TS_809                                                        the black dog      Chorus   C   1.000000
#    TS_1026                surburban legends (taylor's version) (from the vault)      Bridge   C   1.000000
#     TS_993                                       begin again (taylor's version)      Bridge   C   1.000000
#    TS_1025                surburban legends (taylor's version) (from the vault)      Chorus   C   1.000000
#     TS_794                                              ours (taylor's version)       Intro   C   1.000000
#    TS_1028                                                       new year's day      Chorus   C   1.000000
#     TS_157                        all you had to do was stay (taylor's version)      Bridge   C   1.000000
#    TS_1029                                                       new year's day Post-Chorus   C   1.000000
#     TS_994                                       begin again (taylor's version)       Outro   C   1.000000
#     TS_610                                       blank space (taylor's version)       Intro   F   0.833333
#     TS_580                                              right where you left me  Pre-Chorus   F   0.833333
#     TS_611                                       blank space (taylor's version)       Verse   F   0.833333
#     TS_387                                                                peace      Chorus   G   0.833333
#     TS_581                                              right where you left me      Chorus   F   0.833333
#     TS_868             the very first night (taylor's version) (from the vault)       Verse   G   0.833333
#     TS_389                                                  place in this world      Chorus   F   0.833333
#     TS_356                                                                dress      Chorus   F   0.833333
#     TS_865                                  forever & always (taylor's version)      Bridge   G   0.833333
#     TS_866                                  forever & always (taylor's version)       Outro   G   0.833333
#     TS_579                                              right where you left me       Verse   F   0.833333
#     TS_385                                                                peace       Intro   G   0.833333
#     TS_640                                                          the outside      Chorus   F   0.833333
#     TS_864                                  forever & always (taylor's version) Post-Chorus   G   0.833333
#     TS_855           we are never ever getting back together (taylor's version)       Outro   G   0.833333
#     TS_641                                                          the outside Post-Chorus   F   0.833333
#     TS_660                                                             cardigan       Verse   F   0.833333
#     TS_358                                                                dress       Outro   F   0.833333
#     TS_662                                                             cardigan Post-Chorus   F   0.833333
#     TS_570                                                     invisible string       Verse   G   0.833333
#     TS_569                                                     invisible string       Intro   G   0.833333
#     TS_386                                                                peace       Verse   G   0.833333
#     TS_383                                                  i did something bad      Bridge   G   0.833333
#     TS_384                                                  i did something bad       Outro   G   0.833333
#     TS_613                                       blank space (taylor's version)      Bridge   F   0.833333
#     TS_371                                     new romantics (taylor's version)      Chorus   G   0.833333
#     TS_622                                                       i hate it here       Outro   G   0.833333
#     TS_623                                     the last time (taylor's version)       Intro   G   0.833333
#     TS_624                                     the last time (taylor's version)       Verse   G   0.833333
#     TS_625                                     the last time (taylor's version)  Pre-Chorus   G   0.833333
#     TS_597                                     never grow up (taylor's version)  Pre-Chorus   G   0.833333
#     TS_454                                                         the prophecy      Chorus   F   0.833333
#     TS_627                                     the last time (taylor's version)      Bridge   G   0.833333
#     TS_808                                                        the black dog  Pre-Chorus   F   0.833333
#     TS_638                                                          the outside       Intro   F   0.833333
#     TS_374                                                            cassandra       Verse   F   0.833333
#     TS_805                                                           the bolter      Bridge   G   0.833333
#     TS_375                                                            cassandra  Pre-Chorus   F   0.833333
#     TS_376                                                            cassandra      Chorus   G   0.833333
#     TS_583                                              right where you left me       Outro   F   0.833333
#     TS_612                                       blank space (taylor's version)      Chorus   F   0.833333
#     TS_810                                                        the black dog      Bridge   F   0.833333
#     TS_379                                                  i did something bad       Intro   G   0.833333
#     TS_380                                                  i did something bad       Verse   G   0.833333
#     TS_381                                                  i did something bad  Pre-Chorus   G   0.833333
#     TS_599                                     never grow up (taylor's version)      Bridge   G   0.833333
#     TS_639                                                          the outside       Verse   F   0.833333
#     TS_382                                                  i did something bad      Chorus   G   0.833333
#     TS_437                                                     no body no crime       Intro   G   0.833333
#     TS_548                                                           mirrorball       Intro   G   0.833333
#     TS_683                                    jump then fall (taylor's version)  Pre-Chorus   G   0.833333
#     TS_720                      that’s when (taylor's version) (from the vault)      Bridge   G   0.833333
#     TS_725                        don’t you (taylor's version) (from the vault)      Bridge   F   0.833333
#     TS_796                                              ours (taylor's version)      Chorus   F   0.833333
#     TS_423                                                            gold rush  Pre-Chorus   G   0.833333
#     TS_837                                                     king of my heart      Bridge   G   0.833333
#     TS_518                                                               august       Outro   F   0.833333
#     TS_517                                                               august      Bridge   F   0.833333
#     TS_516                                                               august      Chorus   F   0.833333
#     TS_515                                                               august       Verse   F   0.833333
#     TS_427                                          dancing with our hands tied       Intro   F   0.833333
#     TS_442                                                     no body no crime       Outro   G   0.833333
#     TS_730                                                      how did it end?       Intro   F   0.833333
#     TS_731                                                      how did it end?       Verse   F   0.833333
#     TS_511                 state of grace (acoustic version) (taylor's version)       Outro   G   0.833333
#     TS_428                                          dancing with our hands tied       Verse   F   0.833333
#     TS_429                                          dancing with our hands tied  Pre-Chorus   F   0.833333
#     TS_732                                                      how did it end?      Chorus   F   0.833333
#     TS_741                                            change (taylor's version)       Intro   F   0.833333
#     TS_742                                            change (taylor's version)       Verse   F   0.833333
#     TS_744                                            change (taylor's version)      Chorus   F   0.833333
#     TS_745                                            change (taylor's version)      Bridge   F   0.833333
#     TS_746                                            change (taylor's version)       Outro   F   0.833333
#     TS_749                     bye bye baby (taylor's version) (from the vault)      Chorus   F   0.833333
#     TS_759                                        love story (taylor's version)  Pre-Chorus   G   0.833333
#     TS_485                                     chloe or sam or sophia or marcus       Outro   F   0.833333
#     TS_430                                          dancing with our hands tied      Chorus   F   0.833333
#     TS_482                                     chloe or sam or sophia or marcus       Verse   F   0.833333
#     TS_432                                          dancing with our hands tied       Outro   F   0.833333
#     TS_439                                                     no body no crime      Chorus   G   0.833333
#     TS_434                                                                 hoax      Chorus   F   0.833333
#     TS_721                      that’s when (taylor's version) (from the vault)       Outro   F   0.833333
#     TS_719                      that’s when (taylor's version) (from the vault)      Chorus   F   0.833333
#     TS_687                                       untouchable (taylor's version)       Intro   G   0.833333
#     TS_718                      that’s when (taylor's version) (from the vault)  Pre-Chorus   G   0.833333
#     TS_552                                                           mirrorball       Outro   G   0.833333
#     TS_688                                       untouchable (taylor's version)       Verse   G   0.833333
#     TS_403                                                    should've said no       Verse   G   0.833333
#     TS_690                                       untouchable (taylor's version)      Chorus   F   0.833333
#     TS_438                                                     no body no crime       Verse   G   0.833333
#     TS_691                                       untouchable (taylor's version) Post-Chorus   G   0.833333
#     TS_693                               the way i loved you (taylor's version)       Intro   F   0.833333
#     TS_407                                      the smallest man who ever lived      Chorus   G   0.833333
#     TS_544                              run (taylor's version) (from the vault)  Pre-Chorus   F   0.833333
#     TS_694                               the way i loved you (taylor's version)       Verse   F   0.833333
#     TS_695                               the way i loved you (taylor's version)      Chorus   F   0.833333
#     TS_696                               the way i loved you (taylor's version)      Bridge   G   0.833333
#     TS_697                               the way i loved you (taylor's version)       Outro   G   0.833333
#     TS_698                                          fearless (taylor's version)       Intro   F   0.833333
#     TS_699                                          fearless (taylor's version)       Verse   F   0.833333
#     TS_700                                          fearless (taylor's version)      Chorus   F   0.833333
#     TS_701                                          fearless (taylor's version) Post-Chorus   G   0.833333
#     TS_535                                                       hits different       Outro   F   0.833333
#     TS_534                                                       hits different      Bridge   F   0.833333
#     TS_533                                                       hits different Post-Chorus   F   0.833333
#     TS_532                                                       hits different      Chorus   F   0.833333
#     TS_531                                                       hits different       Verse   F   0.833333
#     TS_530                                                       hits different       Intro   F   0.833333
#     TS_703                                          fearless (taylor's version)       Outro   F   0.833333
#     TS_716                      that’s when (taylor's version) (from the vault)       Intro   F   0.833333
#     TS_817                                                        the great war       Verse   F   0.833333
#     TS_526                                      the last great american dynasty       Verse   G   0.833333
#     TS_525                                      the last great american dynasty       Intro   G   0.833333
#     TS_717                      that’s when (taylor's version) (from the vault)       Verse   F   0.833333
#     TS_357                                                                dress      Bridge   F   0.833333
#     TS_001                                                                seven       Verse   G   0.833333
#     TS_355                                                                dress  Pre-Chorus   F   0.833333
#     TS_084                    electric touch(taylor's version) (from the vault)       Verse   G   0.833333
#     TS_113                                                               willow      Chorus   G   0.833333
#    TS_1040                                                             marjorie       Intro   F   0.833333
#     TS_109                                          would've could've should’ve      Bridge   G   0.833333
#     TS_108                                          would've could've should’ve      Chorus   G   0.833333
#    TS_1042                                                             marjorie  Pre-Chorus   F   0.833333
#     TS_103                                                22 (taylor's version)      Chorus   G   0.833333
#     TS_102                                                22 (taylor's version)  Pre-Chorus   G   0.833333
#     TS_101                                                22 (taylor's version)       Verse   G   0.833333
#     TS_100                                                22 (taylor's version)       Intro   G   0.833333
#     TS_099                                                                lover       Outro   G   0.833333
#     TS_098                                                                lover      Bridge   G   0.833333
#     TS_097                                                                lover      Chorus   G   0.833333
#     TS_096                                                                lover       Verse   G   0.833333
#     TS_095                                                                lover       Intro   G   0.833333
#     TS_093                               welcome to new york (taylor's version)      Chorus   G   0.833333
#    TS_1045                                                             marjorie       Outro   G   0.833333
#     TS_089                                               teardrops in my guitar      Bridge   G   0.833333
#     TS_354                                                                dress       Verse   F   0.833333
#     TS_120                                        i'm only me when i'm with you      Bridge   F   0.833333
#     TS_124                                    wildest dreams (taylor's version)  Pre-Chorus   F   0.833333
#     TS_151           when emma fall in love (taylor's version) (from the vault)      Chorus   G   0.833333
#     TS_197                                         long live (taylor's version)      Chorus   G   0.833333
#     TS_196                                         long live (taylor's version)       Verse   G   0.833333
#     TS_195                                         long live (taylor's version)       Intro   G   0.833333
#     TS_193                                    stay stay stay (taylor's version)      Chorus   G   0.833333
#     TS_958                                                            bejeweled       Intro   G   0.833333
#     TS_990                                       begin again (taylor's version)       Intro   G   0.833333
#     TS_991                                       begin again (taylor's version)       Verse   G   0.833333
#    TS_1005                                                             gorgeous  Pre-Chorus   F   0.833333
#     TS_127                                         speak now (taylor's version)       Intro   G   0.833333
#    TS_1007                                                             gorgeous      Bridge   F   0.833333
#    TS_1012                                                                 loml Post-Chorus   F   0.833333
#     TS_135                                          superman (taylor's version)      Chorus   G   0.833333
#     TS_133                                          superman (taylor's version)       Verse   G   0.833333
#     TS_132                                          superman (taylor's version)       Intro   G   0.833333
#     TS_130                                         speak now (taylor's version)      Chorus   G   0.833333
#     TS_128                                         speak now (taylor's version)       Verse   G   0.833333
#     TS_085                    electric touch(taylor's version) (from the vault)      Chorus   G   0.833333
#     TS_083                    electric touch(taylor's version) (from the vault)       Intro   G   0.833333
#     TS_204                             today was a fairytale (taylor's version)       Intro   G   0.833333
#    TS_1073                                                         coney island       Outro   F   0.833333
#     TS_039                                           fifteen (taylor's version)      Chorus   G   0.833333
#     TS_038                                           fifteen (taylor's version)       Verse   G   0.833333
#     TS_037                                           fifteen (taylor's version)       Intro   G   0.833333
#    TS_1120                                    you're losing me (from the vault)  Pre-Chorus   G   0.833333
#    TS_1123                                    you're losing me (from the vault)       Outro   G   0.833333
#     TS_031                                                            mad woman       Intro   F   0.833333
#     TS_029                                                           tim mcgraw      Bridge   F   0.833333
#     TS_026                          'slut!' (taylor's version) (from the vault)       Outro   G   0.833333
#     TS_024                          'slut!' (taylor's version) (from the vault)      Chorus   G   0.833333
#     TS_020                        florida!!! (featuring florence + the machine)      Bridge   G   0.833333
#     TS_019                        florida!!! (featuring florence + the machine)      Chorus   G   0.833333
#     TS_018                        florida!!! (featuring florence + the machine)  Pre-Chorus   F   0.833333
#     TS_017                        florida!!! (featuring florence + the machine)       Verse   F   0.833333
#     TS_013                                                       the manuscript      Bridge   G   0.833333
#     TS_010                                                        midnight rain      Bridge   F   0.833333
#     TS_008                                                        midnight rain       Verse   F   0.833333
#    TS_1141                                                  tis the damn season      Bridge   F   0.833333
#     TS_040                                           fifteen (taylor's version) Post-Chorus   G   0.833333
#     TS_042                                           fifteen (taylor's version)       Outro   G   0.833333
#    TS_1118                                                     it’'s time to go       Outro   G   0.833333
#     TS_066                                                            false god      Chorus   G   0.833333
#     TS_075                                       tell me why (taylor's version)      Chorus   G   0.833333
#     TS_073                                                            invisible       Outro   G   0.833333
#     TS_072                                                            invisible      Bridge   G   0.833333
#     TS_071                                                            invisible      Chorus   G   0.833333
#     TS_069                                                            invisible       Verse   G   0.833333
#     TS_068                                                            invisible       Intro   G   0.833333
#     TS_067                                                            false god       Outro   G   0.833333
#     TS_062                              sad beautiful tragic (taylor's version)      Chorus   G   0.833333
#    TS_1117                                                     it’'s time to go      Bridge   G   0.833333
#     TS_061                              sad beautiful tragic (taylor's version)       Verse   G   0.833333
#     TS_060                              sad beautiful tragic (taylor's version)       Intro   G   0.833333
#    TS_1078                                                      illicit affairs       Outro   G   0.833333
#    TS_1109                                                                the 1       Intro   F   0.833333
#    TS_1110                                                                the 1       Verse   F   0.833333
#    TS_1111                                                                the 1  Pre-Chorus   F   0.833333
#     TS_047                                                       stay beautiful      Bridge   F   0.833333
#     TS_200                                                       so high school      Chorus   G   0.833333
#     TS_303                                                              the man      Chorus   F   0.833333
#     TS_205                             today was a fairytale (taylor's version)       Verse   G   0.833333
#     TS_334                                                          cold as you      Chorus   F   0.833333
#     TS_301                                                              the man       Verse   F   0.833333
#     TS_260                                                        ready for it?      Chorus   G   0.833333
#     TS_302                                                              the man  Pre-Chorus   F   0.833333
#     TS_319                                                             end game  Pre-Chorus   F   0.833333
#     TS_255                                                          dear reader      Bridge   F   0.833333
#     TS_895 all too well (10 minute version) (taylor's version) (from the vault)       Outro   F   0.833333
#     TS_333                                                          cold as you       Verse   F   0.833333
#     TS_337         i bet you think about me (taylor's version) (from the vault)      Chorus   F   0.833333
# ...
#     TS_554                                                 but daddy i love him  Pre-Chorus  C#   0.166667
#    TS_1082                                           i look in people's windows      Chorus  C#   0.166667
#    TS_1081                                           i look in people's windows  Pre-Chorus  C#   0.166667
#    TS_1080                                           i look in people's windows       Verse  C#   0.166667
#    TS_1079                                           i look in people's windows       Intro  C#   0.166667
#     TS_284                                           exile (featuring bon iver)      Chorus   B   0.166667
#     TS_753                mr perfectly fine (taylor's version) (from the vault)  Pre-Chorus   B   0.166667
#     TS_755                mr perfectly fine (taylor's version) (from the vault)      Bridge   B   0.166667
#     TS_078                                                             down bad       Verse   B   0.166667
#     TS_657                                       hey stephen (taylor's version) Post-Chorus  C#   0.166667
#     TS_079                                                             down bad  Pre-Chorus   B   0.166667
#    TS_1161                                  you’re not sorry (taylor's version)      Chorus  C#   0.166667
#     TS_081                                                             down bad      Bridge   B   0.166667
#     TS_756                mr perfectly fine (taylor's version) (from the vault)       Outro   B   0.166667
#     TS_541                                                            clara bow       Outro   B   0.166667
#    TS_1066                                         superstar (taylor's version)      Chorus   B   0.166667
#     TS_082                                                             down bad       Outro   B   0.166667
#     TS_567                                  back to december (taylor's version)      Bridge   B   0.166667
#     TS_761                                        love story (taylor's version)      Bridge   B   0.166667
#     TS_762                                        love story (taylor's version)       Outro   B   0.166667
#    TS_1086                             babe (taylor's version) (from the vault)      Chorus  C#   0.166667
#     TS_293                                      the best day (taylor's version)       Verse  C#   0.166667
#     TS_391                                                  place in this world       Outro  C#   0.166667
#    TS_1098                    i can see you (taylor's version) (from the vault)      Chorus   B   0.166667
#     TS_048                                                       stay beautiful       Outro  C#   0.166667
#     TS_736                                 come back be here (taylor's version)  Pre-Chorus   B   0.166667
#     TS_738                                 come back be here (taylor's version) Post-Chorus   B   0.166667
#     TS_709                                you belong with me (taylor's version)       Outro  C#   0.166667
#    TS_1145                                               you're on your own kid      Chorus   B   0.166667
#    TS_1061                           i knew you were trouble (taylor's version)      Bridge   B   0.166667
#     TS_650                                             style (taylor's version)       Verse   B   0.166667
#     TS_388                                                  place in this world       Verse  C#   0.166667
#    TS_1099                    i can see you (taylor's version) (from the vault)       Outro   B   0.166667
#    TS_1097                    i can see you (taylor's version) (from the vault)  Pre-Chorus   B   0.166667
#     TS_715                        the other side of the door (taylor's version)       Outro   B   0.166667
#     TS_327                                           breathe (taylor's version)       Verse  C#   0.166667
#     TS_044                                                       stay beautiful       Verse  C#   0.166667
#     TS_326                                           breathe (taylor's version)       Intro  C#   0.166667
#     TS_504                                         enchanted (taylor's version)      Bridge  Db   0.166667
#     TS_503                                         enchanted (taylor's version)      Chorus  Db   0.166667
#     TS_619                                                       i hate it here       Verse   B   0.166667
#     TS_553                                                 but daddy i love him       Verse   B   0.166667
#     TS_659                                       hey stephen (taylor's version)       Outro  C#   0.166667
#    TS_1155                                       holy ground (taylor's version)      Chorus   B   0.166667
#    TS_1152                                                         cruel summer       Outro   B   0.166667
#     TS_080                                                             down bad      Chorus   B   0.166667
#    TS_1060                           i knew you were trouble (taylor's version) Post-Chorus   B   0.166667
#     TS_118                                        i'm only me when i'm with you  Pre-Chorus  C#   0.166667
#     TS_122                                    wildest dreams (taylor's version)       Intro  C#   0.166667
#     TS_123                                    wildest dreams (taylor's version)       Verse  C#   0.166667
#    TS_1023                                                                  me!       Outro   B   0.166667
#     TS_248                                                             epiphany       Verse  C#   0.166667
#     TS_247                                                             epiphany       Intro  C#   0.166667
#     TS_243                               miss americana & the heartbreak prince       Verse   B   0.166667
#     TS_780                                             clean (taylor's version)  Pre-Chorus   B   0.166667
#     TS_141                                       i almost do (taylor's version)      Bridge  C#   0.166667
#     TS_784                                             clean (taylor's version)       Outro   B   0.166667
#     TS_629                                                                  ivy       Verse   B   0.166667
#     TS_642                                                       guilty as sin?       Verse   B   0.166667
#     TS_203                                                       so high school       Outro   B   0.166667
#     TS_189                                                            happiness      Bridge   B   0.166667
#     TS_188                                                            happiness      Chorus   B   0.166667
#     TS_995                                    fortnight (featuring post malone)       Intro   B   0.166667
#     TS_187                                                            happiness       Verse   B   0.166667
#     TS_186                                                            happiness       Intro   B   0.166667
#     TS_462                                          innocent (taylor's version)       Intro  C#   0.166667
#     TS_463                                          innocent (taylor's version)       Verse  C#   0.166667
#     TS_474                                   the story of us (taylor's version)  Pre-Chorus   B   0.166667
#     TS_464                                          innocent (taylor's version)  Pre-Chorus   B   0.166667
#     TS_466                                          innocent (taylor's version)      Bridge  C#   0.166667
#     TS_467                                          innocent (taylor's version)       Outro  C#   0.166667
#     TS_468                                              mean (taylor's version)       Verse  C#   0.166667
#     TS_637                       better man (taylor's version) (from the vault)       Outro   B   0.166667
#     TS_472                                   the story of us (taylor's version)       Intro   B   0.166667
#     TS_469                                              mean (taylor's version)  Pre-Chorus   B   0.166667
#     TS_121                                        i'm only me when i'm with you       Outro  C#   0.166667
#     TS_782                                             clean (taylor's version) Post-Chorus   B   0.166667
#     TS_480                                         dear john (taylor's version)      Bridge  C#   0.166667
#    TS_1039                                                       so long london       Outro   B   0.166667
#     TS_769                                                        the albatross       Verse   B   0.166667
#     TS_768                                         this love (taylor's version)      Bridge   B   0.166667
#    TS_1050                               better than revenge (taylor's version)       Outro   B   0.166667
#    TS_1046                               better than revenge (taylor's version)       Intro   B   0.166667
#     TS_922                                                             evermore      Chorus  C#   0.166667
#     TS_110                                          would've could've should’ve       Outro   B   0.166667
#    TS_1047                               better than revenge (taylor's version)       Verse   B   0.166667
#     TS_921                                                             evermore       Verse  C#   0.166667
#     TS_267                                                          so it goes…       Verse   B   0.166667
#     TS_920                                                             evermore       Intro  C#   0.166667
#    TS_1054                                                           mastermind      Chorus  C#   0.166667
#     TS_266                                                          so it goes…       Intro   B   0.166667
#     TS_114                                                               willow      Bridge   B   0.166667
#     TS_268                                                          so it goes…  Pre-Chorus   B   0.166667
#    TS_1048                               better than revenge (taylor's version)      Chorus   B   0.166667
#     TS_190                                                            happiness       Outro  F#   0.000000
#     TS_790                                                call it what you want       Verse  F#   0.000000
#     TS_714                        the other side of the door (taylor's version)      Bridge  F#   0.000000
#     TS_924                                                             evermore      Bridge  F#   0.000000
#     TS_283                                           exile (featuring bon iver)       Verse  F#   0.000000
#     TS_417                                                    snow on the beach      Chorus  F#   0.000000
#     TS_656                                       hey stephen (taylor's version)      Chorus  F#   0.000000
#     TS_282                                           exile (featuring bon iver)       Intro  F#   0.000000
#     TS_705                                you belong with me (taylor's version)       Verse  F#   0.000000
#     TS_185                                                    imgonnagetyouback      Bridge  F#   0.000000
#     TS_923                                                             evermore Post-Chorus  F#   0.000000
#     TS_707                                you belong with me (taylor's version)      Chorus  F#   0.000000
#     TS_654                                       hey stephen (taylor's version)       Intro  F#   0.000000
#     TS_704                                you belong with me (taylor's version)       Intro  F#   0.000000
#     TS_861                  forever & always (piano version) (taylor’s version)       Outro  F#   0.000000
#     TS_860                  forever & always (piano version) (taylor’s version)      Bridge  F#   0.000000
#     TS_859                  forever & always (piano version) (taylor’s version) Post-Chorus  F#   0.000000
#     TS_182                                                    imgonnagetyouback       Verse  F#   0.000000
#     TS_398                                                    this is me trying      Chorus  F#   0.000000
#    TS_1056                           i knew you were trouble (taylor's version)       Intro  F#   0.000000
#    TS_1057                           i knew you were trouble (taylor's version)       Verse  F#   0.000000
#     TS_655                                       hey stephen (taylor's version)       Verse  F#   0.000000
#     TS_426                                                            gold rush       Outro  F#   0.000000
#     TS_418                                                    snow on the beach Post-Chorus  F#   0.000000
#     TS_925                                                             evermore       Outro  F#   0.000000
#     TS_294                                      the best day (taylor's version)      Chorus  F#   0.000000
#     TS_250                                                             epiphany      Bridge  F#   0.000000
#     TS_668                                                              dorthea Post-Chorus  F#   0.000000
#     TS_669                                                              dorthea       Outro  F#   0.000000
#     TS_328                                           breathe (taylor's version)  Pre-Chorus  F#   0.000000
#     TS_329                                           breathe (taylor's version)      Chorus  F#   0.000000
#     TS_666                                                              dorthea  Pre-Chorus  F#   0.000000
#     TS_331                                           breathe (taylor's version)       Outro  F#   0.000000
#     TS_285                                           exile (featuring bon iver) Post-Chorus  F#   0.000000
#     TS_424                                                            gold rush      Chorus  F#   0.000000
#     TS_422                                                            gold rush       Verse  F#   0.000000
#     TS_617                            everything has changed (taylor's version)      Chorus  F#   0.000000
#     TS_616                            everything has changed (taylor's version)  Pre-Chorus  F#   0.000000
#     TS_615                            everything has changed (taylor's version)       Verse  F#   0.000000
#    TS_1058                           i knew you were trouble (taylor's version)  Pre-Chorus  F#   0.000000
#     TS_456                                                         the prophecy       Outro  F#   0.000000
#     TS_400                                                    this is me trying      Bridge  F#   0.000000
#     TS_421                                                            gold rush       Intro  F#   0.000000
#     TS_614                            everything has changed (taylor's version)       Intro  F#   0.000000
#     TS_787                                               a perfectly good heart  Pre-Chorus  F#   0.000000
#     TS_361                                                            the lakes      Chorus  F#   0.000000
#     TS_728                                            bigger than the whole sky      Chorus  F#   0.000000
#     TS_420                                                    snow on the beach       Outro  F#   0.000000
#     TS_419                                                    snow on the beach      Bridge  F#   0.000000
#     TS_364                                                           london boy       Intro  F#   0.000000
#     TS_727                                            bigger than the whole sky       Verse  F#   0.000000
#     TS_365                                                           london boy       Verse  F#   0.000000
#     TS_295                                      the best day (taylor's version)      Bridge  F#   0.000000
#     TS_367                                                           london boy      Bridge  F#   0.000000
#     TS_366                                                           london boy      Chorus  F#   0.000000

# %% [markdown]
# ---
# ## Progression Score
#
# Similarity between two chord progressions (sequences of Roman numerals).
#
# ### Pluggable design
# `progression_score(prog_a, prog_b, sim_fn=lcs_similarity)` accepts any function with the signature:
# ```python
# sim_fn(seq_a: list[str], seq_b: list[str]) -> float  # in [0, 1]
# ```
# Three built-in options are provided below.

# %%
# ── Similarity function 1: Longest Common Subsequence (DEFAULT) ──────────────
# Allows gaps; good at catching shared harmonic motifs regardless of insertions.

def lcs_length(a: list, b: list) -> int:
    """Standard LCS length via dynamic programming."""
    m, n = len(a), len(b)
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if a[i - 1] == b[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
    return dp[m][n]

def lcs_similarity(a: list, b: list) -> float:
    """LCS length normalized by the longer sequence. Range: [0, 1]."""
    if not a and not b:
        return 1.0
    if not a or not b:
        return 0.0
    return lcs_length(a, b) / max(len(a), len(b))


# ── Similarity function 2: Longest Common Substring ──────────────────────────
# Must be contiguous; rewards exact shared riffs.

def lcsubstring_length(a: list, b: list) -> int:
    """Length of the longest contiguous common block."""
    m, n = len(a), len(b)
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    best = 0
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if a[i - 1] == b[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
                best = max(best, dp[i][j])
    return best

def lcsubstring_similarity(a: list, b: list) -> float:
    """Longest common substring normalized by the longer sequence. Range: [0, 1]."""
    if not a and not b:
        return 1.0
    if not a or not b:
        return 0.0
    return lcsubstring_length(a, b) / max(len(a), len(b))


# ── Similarity function 3: Levenshtein (edit distance) ───────────────────────
# Counts substitutions, insertions, deletions; penalizes reordering.

def levenshtein_distance(a: list, b: list) -> int:
    m, n = len(a), len(b)
    dp = list(range(n + 1))
    for i in range(1, m + 1):
        prev = dp[:]
        dp[0] = i
        for j in range(1, n + 1):
            if a[i - 1] == b[j - 1]:
                dp[j] = prev[j - 1]
            else:
                dp[j] = 1 + min(prev[j], dp[j - 1], prev[j - 1])
    return dp[n]

def levenshtein_similarity(a: list, b: list) -> float:
    """1 - normalized edit distance. Range: [0, 1]."""
    if not a and not b:
        return 1.0
    if not a or not b:
        return 0.0
    return 1.0 - levenshtein_distance(a, b) / max(len(a), len(b))


# ── Quick comparison of all three ────────────────────────────────────────────
examples = [
    (["I", "V", "vi", "IV"], ["I", "V", "vi", "IV"]),   # identical
    (["I", "V", "vi", "IV"], ["I", "vi", "IV"]),          # one chord dropped
    (["I", "V", "vi", "IV"], ["V", "vi", "IV", "I"]),     # rotation
    (["I", "V", "vi", "IV"], ["ii", "V", "I"]),           # partial overlap
]

fns = [("LCS", lcs_similarity), ("Substring", lcsubstring_similarity), ("Levenshtein", levenshtein_similarity)]

print(f"{'Pair':<45} {'LCS':>6} {'Substr':>8} {'Leven':>8}")
print("-" * 70)
for a, b in examples:
    label = f"{a} vs {b}"
    scores = [fn(a, b) for _, fn in fns]
    print(f"{label:<45} {scores[0]:>6.3f} {scores[1]:>8.3f} {scores[2]:>8.3f}")
# Out:
# Pair                                             LCS   Substr    Leven
# ----------------------------------------------------------------------
# ['I', 'V', 'vi', 'IV'] vs ['I', 'V', 'vi', 'IV']  1.000    1.000    1.000
# ['I', 'V', 'vi', 'IV'] vs ['I', 'vi', 'IV']    0.750    0.500    0.750
# ['I', 'V', 'vi', 'IV'] vs ['V', 'vi', 'IV', 'I']  0.750    0.750    0.500
# ['I', 'V', 'vi', 'IV'] vs ['ii', 'V', 'I']     0.250    0.250    0.250

# %%
def progression_score(
    prog_a: list[str],
    prog_b: list[str],
    sim_fn=lcs_similarity,   # swap to lcsubstring_similarity or levenshtein_similarity
) -> float:
    """
    Similarity score in [0, 1] between two Roman-numeral progressions.

    Parameters
    ----------
    prog_a, prog_b : list[str]
        Chord progressions as Roman-numeral token lists.
    sim_fn : callable
        Any function (list, list) -> float in [0, 1].
        Built-ins: lcs_similarity, lcsubstring_similarity, levenshtein_similarity.
    """
    return sim_fn(prog_a, prog_b)

# %% [markdown]
# ---
# ## Score All Snippets Against a Query
#
# Given a query `(key, progression)`, compute `key_score` and `progression_score` for every snippet in the dataset.

# %%
def score_all(
    query_key: str,
    query_progression: list[str],
    df: pd.DataFrame,
    sim_fn=lcs_similarity,
    key_weight: float = 0.5,
    prog_weight: float = 0.5,
) -> pd.DataFrame:
    """
    Score every snippet in df against a query (key, progression).

    Returns a copy of df with three added columns:
      - key_score         : circle-of-fifths similarity
      - progression_score : sequence similarity via sim_fn
      - total_score       : weighted sum of the two
    Sorted by total_score descending.
    """
    result = df.copy()
    result["key_score"] = result["key"].apply(lambda k: key_score(query_key, k))
    result["progression_score"] = result["roman_progression"].apply(
        lambda p: progression_score(query_progression, p, sim_fn=sim_fn)
    )
    result["total_score"] = (
        key_weight * result["key_score"] + prog_weight * result["progression_score"]
    )
    return result.sort_values("total_score", ascending=False).reset_index(drop=True)


# ── Demo: All Too Well (Taylor's Version) — Chorus ───────────────────────────
query = df[
    (df["song_title"] == "all too well (taylor's version)") &
    (df["section"] == "Chorus")
].iloc[0]

print(f"Query: [{query['snippet_id']}] {query['song_title']} — {query['section']}")
print(f"  Key: {query['key']}  |  Progression: {query['roman_progression']}")
print()

results = score_all(query["key"], query["roman_progression"], df)
print(results[["snippet_id", "song_title", "section", "key", "key_score", "progression_score", "total_score"]].head(25).to_string(index=False))
# Out:
# Query: [TS_887] all too well (taylor's version) — Chorus
#   Key: C  |  Progression: ['I', 'V', 'vi', 'IV']
#
# snippet_id                                                           song_title    section key  key_score  progression_score  total_score
#     TS_913                                                      cornelia street      Outro   C   1.000000                1.0     1.000000
#     TS_902                                                   champagne problems     Chorus   C   1.000000                1.0     1.000000
#     TS_884                                      all too well (taylor's version)      Intro   C   1.000000                1.0     1.000000
#     TS_885                                      all too well (taylor's version)      Verse   C   1.000000                1.0     1.000000
#     TS_887                                      all too well (taylor's version)     Chorus   C   1.000000                1.0     1.000000
#     TS_888                                      all too well (taylor's version)     Bridge   C   1.000000                1.0     1.000000
#     TS_890 all too well (10 minute version) (taylor's version) (from the vault)      Intro   C   1.000000                1.0     1.000000
#     TS_891 all too well (10 minute version) (taylor's version) (from the vault)      Verse   C   1.000000                1.0     1.000000
#     TS_893 all too well (10 minute version) (taylor's version) (from the vault)     Chorus   C   1.000000                1.0     1.000000
#     TS_894 all too well (10 minute version) (taylor's version) (from the vault)     Bridge   C   1.000000                1.0     1.000000
#     TS_946                                                           the archer     Bridge   C   1.000000                1.0     1.000000
#     TS_944                                                           the archer Pre-Chorus   C   1.000000                1.0     1.000000
#     TS_898                    we were happy (taylor's version) (from the vault)     Chorus   C   1.000000                1.0     1.000000
#     TS_901                                                   champagne problems      Verse   C   1.000000                1.0     1.000000
#     TS_889                                      all too well (taylor's version)      Outro   C   1.000000                1.0     1.000000
#     TS_907                                  out of the woods (taylor's version)     Bridge   C   1.000000                1.0     1.000000
#     TS_905                                  out of the woods (taylor's version)      Verse   C   1.000000                1.0     1.000000
#     TS_911                                                      cornelia street     Chorus   C   1.000000                1.0     1.000000
#     TS_909                                                      cornelia street      Verse   C   1.000000                1.0     1.000000
#     TS_903                                                   champagne problems     Bridge   C   1.000000                1.0     1.000000
#     TS_906                                  out of the woods (taylor's version)     Chorus   C   1.000000                1.0     1.000000
#     TS_742                                            change (taylor's version)      Verse   F   0.833333                1.0     0.916667
#     TS_741                                            change (taylor's version)      Intro   F   0.833333                1.0     0.916667
#     TS_403                                                    should've said no      Verse   G   0.833333                1.0     0.916667
#     TS_746                                            change (taylor's version)      Outro   F   0.833333                1.0     0.916667

# %%
# ── Compare results across different similarity functions ─────────────────────
SIM_FNS = {
    "LCS": lcs_similarity,
    "Substring": lcsubstring_similarity,
    "Levenshtein": levenshtein_similarity,
}

query = df[
    (df["song_title"] == "all too well (taylor's version)") &
    (df["section"] == "Chorus")
].iloc[0]

print(f"Query: [{query['snippet_id']}] {query['song_title']} — {query['section']}")
print(f"  Key: {query['key']}  |  Progression: {query['roman_progression']}")
print()

for fn_name, fn in SIM_FNS.items():
    top5 = score_all(query["key"], query["roman_progression"], df, sim_fn=fn).head(15)
    print(f"── Top 5 with {fn_name} ──")
    print(top5[["snippet_id", "song_title", "section", "key_score", "progression_score", "total_score"]].to_string(index=False))
    print()
# Out:
# Query: [TS_887] all too well (taylor's version) — Chorus
#   Key: C  |  Progression: ['I', 'V', 'vi', 'IV']
#
# ── Top 5 with LCS ──
# snippet_id                      song_title section  key_score  progression_score  total_score
#     TS_913                 cornelia street   Outro        1.0                1.0          1.0
#     TS_902              champagne problems  Chorus        1.0                1.0          1.0
#     TS_884 all too well (taylor's version)   Intro        1.0                1.0          1.0
#     TS_885 all too well (taylor's version)   Verse        1.0                1.0          1.0
#     TS_887 all too well (taylor's version)  Chorus        1.0                1.0          1.0
#
# ── Top 5 with Substring ──
# snippet_id                      song_title    section  key_score  progression_score  total_score
#     TS_887 all too well (taylor's version)     Chorus        1.0                1.0          1.0
#     TS_902              champagne problems     Chorus        1.0                1.0          1.0
#     TS_888 all too well (taylor's version)     Bridge        1.0                1.0          1.0
#     TS_946                      the archer     Bridge        1.0                1.0          1.0
#     TS_944                      the archer Pre-Chorus        1.0                1.0          1.0
#
# ── Top 5 with Levenshtein ──
# snippet_id                                        song_title    section  key_score  progression_score  total_score
#     TS_907               out of the woods (taylor's version)     Bridge        1.0                1.0          1.0
#     TS_898 we were happy (taylor's version) (from the vault)     Chorus        1.0                1.0          1.0
#     TS_946                                        the archer     Bridge        1.0                1.0          1.0
#     TS_944                                        the archer Pre-Chorus        1.0                1.0          1.0
#     TS_884                   all too well (taylor's version)      Intro        1.0                1.0          1.0
